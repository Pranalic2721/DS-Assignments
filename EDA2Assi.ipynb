# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd

# %%
df =pd.read_csv("/content/adult_with_headers.csv",index_col=0)
df
# Out:
#              workclass  fnlwgt    education  education_num  \
# age
# 39           State-gov   77516    Bachelors             13
# 50    Self-emp-not-inc   83311    Bachelors             13
# 38             Private  215646      HS-grad              9
# 53             Private  234721         11th              7
# 28             Private  338409    Bachelors             13
# ..                 ...     ...          ...            ...
# 27             Private  257302   Assoc-acdm             12
# 40             Private  154374      HS-grad              9
# 58             Private  151910      HS-grad              9
# 22             Private  201490      HS-grad              9
# 52        Self-emp-inc  287927      HS-grad              9
#
#           marital_status          occupation    relationship    race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White     Male
# ...

# %%
df.head()
# Out:
#              workclass  fnlwgt   education  education_num  \
# age
# 39           State-gov   77516   Bachelors             13
# 50    Self-emp-not-inc   83311   Bachelors             13
# 38             Private  215646     HS-grad              9
# 53             Private  234721        11th              7
# 28             Private  338409   Bachelors             13
#
#           marital_status          occupation    relationship    race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White     Male
# 38              Divorced   Handlers-cleaners   Not-in-family   White     Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 28    Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#      capital_gain  capital_loss  hours_per_week  native_country  income
# age
# ...

# %%
df.tail()
# Out:
#          workclass  fnlwgt    education  education_num       marital_status  \
# age
# 27         Private  257302   Assoc-acdm             12   Married-civ-spouse
# 40         Private  154374      HS-grad              9   Married-civ-spouse
# 58         Private  151910      HS-grad              9              Widowed
# 22         Private  201490      HS-grad              9        Never-married
# 52    Self-emp-inc  287927      HS-grad              9   Married-civ-spouse
#
#              occupation relationship    race      sex  capital_gain  \
# age
# 27         Tech-support         Wife   White   Female             0
# 40    Machine-op-inspct      Husband   White     Male             0
# 58         Adm-clerical    Unmarried   White   Female             0
# 22         Adm-clerical    Own-child   White     Male             0
# 52      Exec-managerial         Wife   White   Female         15024
#
#      capital_loss  hours_per_week  native_country  income
# age
# ...

# %%
# Identify numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
numerical_columns
# Out:
# Index(['fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
# Initialize the scalers
standard_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

# %%
# Apply Standard Scaling
df_standard_scaled = df.copy()  # Create a copy to hold the scaled data
df_standard_scaled[numerical_columns] = standard_scaler.fit_transform(df[numerical_columns])
df_standard_scaled.head()
# Out:
#              workclass    fnlwgt   education  education_num  \
# age
# 39           State-gov -1.063611   Bachelors       1.134739
# 50    Self-emp-not-inc -1.008707   Bachelors       1.134739
# 38             Private  0.245079     HS-grad      -0.420060
# 53             Private  0.425801        11th      -1.197459
# 28             Private  1.408176   Bachelors       1.134739
#
#           marital_status          occupation    relationship    race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White     Male
# 38              Divorced   Handlers-cleaners   Not-in-family   White     Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 28    Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#      capital_gain  capital_loss  hours_per_week  native_country  income
# age
# ...

# %%
# Apply Min-Max Scaling
df_min_max_scaled = df.copy()  # Create another copy to hold the min-max scaled data
df_min_max_scaled[numerical_columns] = min_max_scaler.fit_transform(df[numerical_columns])
df_min_max_scaled.head()
# Out:
#              workclass    fnlwgt   education  education_num  \
# age
# 39           State-gov  0.044302   Bachelors       0.800000
# 50    Self-emp-not-inc  0.048238   Bachelors       0.800000
# 38             Private  0.138113     HS-grad       0.533333
# 53             Private  0.151068        11th       0.400000
# 28             Private  0.221488   Bachelors       0.800000
#
#           marital_status          occupation    relationship    race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White     Male
# 38              Divorced   Handlers-cleaners   Not-in-family   White     Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 28    Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#      capital_gain  capital_loss  hours_per_week  native_country  income
# age
# ...

# %%
# Identify the categorical columns that need label encoding
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %%
labelencoder = LabelEncoder()
df['race'] = labelencoder.fit_transform(df['race'])
df.head()
# Out:
#              workclass  fnlwgt   education  education_num  \
# age
# 39           State-gov   77516   Bachelors             13
# 50    Self-emp-not-inc   83311   Bachelors             13
# 38             Private  215646     HS-grad              9
# 53             Private  234721        11th              7
# 28             Private  338409   Bachelors             13
#
#           marital_status          occupation    relationship  race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family     4     Male
# 50    Married-civ-spouse     Exec-managerial         Husband     4     Male
# 38              Divorced   Handlers-cleaners   Not-in-family     4     Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband     2     Male
# 28    Married-civ-spouse      Prof-specialty            Wife     2   Female
#
#      capital_gain  capital_loss  hours_per_week  native_country  income
# age
# ...

# %%
labelencoder = LabelEncoder()
df['workclass'] = labelencoder.fit_transform(df['workclass'])

# %%
labelencoder = LabelEncoder()
df['education'] = labelencoder.fit_transform(df['education'])
labelencoder = LabelEncoder()
df['marital_status'] = labelencoder.fit_transform(df['marital_status'])
labelencoder = LabelEncoder()
df[ 'occupation'] = labelencoder.fit_transform(df[ 'occupation'])
labelencoder = LabelEncoder()
df['relationship'] = labelencoder.fit_transform(df['relationship'])
labelencoder = LabelEncoder()
df['sex'] = labelencoder.fit_transform(df['sex'])
labelencoder = LabelEncoder()
df['native_country'] = labelencoder.fit_transform(df['native_country'])
labelencoder = LabelEncoder()
df['income'] = labelencoder.fit_transform(df['income'])
df.head()
# Out:
#      workclass  fnlwgt  education  education_num  marital_status  occupation  \
# age
# 39           7   77516          9             13               4           1
# 50           6   83311          9             13               2           4
# 38           4  215646         11              9               0           6
# 53           4  234721          1              7               2           6
# 28           4  338409          9             13               2          10
#
#      relationship  race  sex  capital_gain  capital_loss  hours_per_week  \
# age
# 39              1     4    1          2174             0              40
# 50              0     4    1             0             0              13
# 38              1     4    1             0             0              40
# 53              0     2    1             0             0              40
# 28              5     2    0             0             0              40
#
#      native_country  income
# age
# ...

# %% [markdown]
# Feature selection & Feature Engg:

# %%
from pandas import read_csv
import pandas as pd
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest # for univariate selection
from sklearn.feature_selection import chi2

# %%
filename = '/content/adult_with_headers.csv'

# %%
names = ['workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
       'occupation', 'relationship', 'race', 'sex', 'capital_gain',
       'capital_loss', 'hours_per_week', 'native_country', 'income']
df = read_csv(filename, names=names)
array = df.values
df.head()
# Out:
#              workclass  fnlwgt   education  education_num  \
# age          workclass  fnlwgt   education  education_num
# 39           State-gov   77516   Bachelors             13
# 50    Self-emp-not-inc   83311   Bachelors             13
# 38             Private  215646     HS-grad              9
# 53             Private  234721        11th              7
#
#           marital_status          occupation    relationship    race    sex  \
# age       marital_status          occupation    relationship    race    sex
# 39         Never-married        Adm-clerical   Not-in-family   White   Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White   Male
# 38              Divorced   Handlers-cleaners   Not-in-family   White   Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#      capital_gain  capital_loss  hours_per_week  native_country  income
# age  capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
df.shape
# Out:
# (32562, 14)

# %%
# Import the necessary libraries first
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
array = df.values
X = array[:,0:13]
Y = array[:,13]

# %%
names = df.columns
names
# Out:
# Index(['workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'race', 'sex', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'income'],
#       dtype='object')

# %%
df
# Out:
#              workclass  fnlwgt    education  education_num  \
# age          workclass  fnlwgt    education  education_num
# 39           State-gov   77516    Bachelors             13
# 50    Self-emp-not-inc   83311    Bachelors             13
# 38             Private  215646      HS-grad              9
# 53             Private  234721         11th              7
# ..                 ...     ...          ...            ...
# 27             Private  257302   Assoc-acdm             12
# 40             Private  154374      HS-grad              9
# 58             Private  151910      HS-grad              9
# 22             Private  201490      HS-grad              9
# 52        Self-emp-inc  287927      HS-grad              9
#
#           marital_status          occupation    relationship    race      sex  \
# age       marital_status          occupation    relationship    race      sex
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# ...

# %%
dtypedf = df.dtypes
dtypedf
# Out:
# workclass         object
# fnlwgt            object
# education         object
# education_num     object
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain      object
# capital_loss      object
# hours_per_week    object
# native_country    object
# income            object
# dtype: object

# %%
df['education'] = df['education'].astype(str)

# %%
# Feature engg
df.drop('education',axis=1,inplace=True)

# %%
# Then remove Capital-Gain and Capital-Loss
df.drop('capital_gain',axis=1,inplace=True)
df.drop('capital_loss',axis=1,inplace=True)

# %%
df.head()
# Out:
#              workclass  fnlwgt  education_num       marital_status  \
# age          workclass  fnlwgt  education_num       marital_status
# 39           State-gov   77516             13        Never-married
# 50    Self-emp-not-inc   83311             13   Married-civ-spouse
# 38             Private  215646              9             Divorced
# 53             Private  234721              7   Married-civ-spouse
#
#              occupation    relationship    race    sex  hours_per_week  \
# age          occupation    relationship    race    sex  hours_per_week
# 39         Adm-clerical   Not-in-family   White   Male              40
# 50      Exec-managerial         Husband   White   Male              13
# 38    Handlers-cleaners   Not-in-family   White   Male              40
# 53    Handlers-cleaners         Husband   Black   Male              40
#
#      native_country  income
# age  native_country  income
# 39    United-States   <=50K
# 50    United-States   <=50K
# ...

# %%
df.drop('fnlwgt',axis=1,inplace=True) #It is not imp column

# %%
df.head()
# Out:
#              workclass  education_num       marital_status  \
# age          workclass  education_num       marital_status
# 39           State-gov             13        Never-married
# 50    Self-emp-not-inc             13   Married-civ-spouse
# 38             Private              9             Divorced
# 53             Private              7   Married-civ-spouse
#
#              occupation    relationship    race    sex  hours_per_week  \
# age          occupation    relationship    race    sex  hours_per_week
# 39         Adm-clerical   Not-in-family   White   Male              40
# 50      Exec-managerial         Husband   White   Male              13
# 38    Handlers-cleaners   Not-in-family   White   Male              40
# 53    Handlers-cleaners         Husband   Black   Male              40
#
#      native_country  income
# age  native_country  income
# 39    United-States   <=50K
# 50    United-States   <=50K
# 38    United-States   <=50K
# 53    United-States   <=50K

# %%
df['income'].unique()
# Out:
# array(['income', ' <=50K', ' >50K'], dtype=object)

# %%
#making changes as 1: more than 50k & 0: less than 50k
import numpy as np
df['income']=np.where(df['income']=='>50k',1,0)

# %%
df.head()
# Out:
#              workclass  education_num       marital_status  \
# age          workclass  education_num       marital_status
# 39           State-gov             13        Never-married
# 50    Self-emp-not-inc             13   Married-civ-spouse
# 38             Private              9             Divorced
# 53             Private              7   Married-civ-spouse
#
#              occupation    relationship    race    sex  hours_per_week  \
# age          occupation    relationship    race    sex  hours_per_week
# 39         Adm-clerical   Not-in-family   White   Male              40
# 50      Exec-managerial         Husband   White   Male              13
# 38    Handlers-cleaners   Not-in-family   White   Male              40
# 53    Handlers-cleaners         Husband   Black   Male              40
#
#      native_country  income
# age  native_country       0
# 39    United-States       0
# 50    United-States       0
# 38    United-States       0
# 53    United-States       0

# %% [markdown]
# Isolation Forest model:

# %%
from sklearn.ensemble import IsolationForest
import numpy as np
import pandas as pd

# %%
X_train=pd.read_csv('/content/adult_with_headers.csv')
y_train=pd.read_csv('/content/adult_with_headers.csv')

# %%
# Check unique values in the 'workclass' column
print(X_train['workclass'].unique())
# Out:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']

# %%
# Apply One-Hot Encoding to the 'workclass' column
X_train_encoded = pd.get_dummies(X_train, columns=['workclass'], drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
X_train['workclass'] = label_encoder.fit_transform(X_train['workclass'])

# %%
# Identify categorical columns
categorical_cols = X_train.select_dtypes(include=['object']).columns
print(categorical_cols)
# Out:
# Index(['education', 'marital_status', 'occupation', 'relationship', 'race',
#        'sex', 'native_country', 'income'],
#       dtype='object')

# %%
# Apply One-Hot Encoding to all categorical columns
X_train_encoded = pd.get_dummies(X_train, drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Apply Label Encoding to all categorical columns
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for col in categorical_cols:
    X_train[col] = label_encoder.fit_transform(X_train[col])

# %%
# Initialize the Isolation Forest model
iso_forest = IsolationForest(contamination=0.05, random_state=42)
outlier_pred = iso_forest.fit_predict(X_train_encoded) # -1 indicates an outlier, 1 indicates an inlier

# %%
# Keep only the inliers
X_train_inliers = X_train[outlier_pred == 1]
y_train_inliers = y_train[outlier_pred == 1]

# %% [markdown]
# PPS:

# %%
! pip install ppscore

# %%
pip install --upgrade ppscore

# %%
import ppscore
print(ppscore.__version__)
# Out:
# 1.3.0

# %%
import pandas as pd
import ppscore as pps
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sn
from collections import Counter

warnings.filterwarnings("ignore")

# %%
X_train=pd.read_csv('/content/adult_with_headers.csv')
y_train=pd.read_csv('/content/adult_with_headers.csv')
df_sample=pd.read_csv('/content/adult_with_headers.csv')

# %%
print(X_train.dtypes)
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
X_train_encoded = pd.get_dummies(X_train, drop_first=True)

# %%
print(X_train_encoded.head())
# Out:
#    age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  \
# 0                       0                     0                        0
# 1                       0                     0                        0
# 2                       0                     0                        0
# 3                       0                     0                        0
# 4                       0                     0                        0
#
#    workclass_ Private  ...  native_country_ Puerto-Rico  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()
X_train['age'] = label_encoder.fit_transform(X_train['age'])

# %%
pps.matrix(df)
# Out:
#              x               y       ppscore            case  is_valid_score  \
# 0    workclass       workclass  1.000000e+00  predict_itself            True
# 1    workclass          fnlwgt  9.000906e-06  classification            True
# 2    workclass       education  2.770051e-02  classification            True
# 3    workclass   education_num  2.756551e-02  classification            True
# 4    workclass  marital_status  0.000000e+00  classification            True
# ..         ...             ...           ...             ...             ...
# 191     income    capital_gain  2.935852e-07  classification            True
# 192     income    capital_loss  5.087981e-07  classification            True
# 193     income  hours_per_week  1.087006e-07  classification            True
# 194     income  native_country  2.377774e-07  classification            True
# 195     income          income  1.000000e+00  predict_itself            True
#
# ...

# %%
pps.score(df,"x","y")
# Out:
# {'x': 'x',
#  'y': 'y',
#  'ppscore': 0,
#  'case': 'classification',
#  'is_valid_score': True,
#  'metric': 'weighted F1',
#  'baseline_score': 0.1111111111111111,
#  'model_score': 0.0,
#  'model': DecisionTreeClassifier()}

# %% [markdown]
# Correlation:

# %%
plt.figure(figsize=(16,12))
sns.heatmap(X_train.corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >
